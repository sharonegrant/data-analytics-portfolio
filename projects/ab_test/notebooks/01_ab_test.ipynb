# %% [markdown]
# # A/B Test Demo – Landing Page Experiment
#
# This notebook simulates a simple A/B test (Control vs Variant) and walks through
# conversion rates, uplift, a basic significance test, and a business-facing summary.

# %%
import numpy as np
import pandas as pd
import math

np.random.seed(42)
